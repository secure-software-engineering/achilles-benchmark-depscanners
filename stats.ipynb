# %%
import pandas
import os
import matplotlib.pyplot as plt
import json

# %%
import fnmatch
import io

def genDataframeFor(filenamePattern="*.json"):
    matches = []

    for root, dirnames, filenames in os.walk('./detection'):
        for filename in fnmatch.filter(filenames, filenamePattern):
            matches.append(os.path.join(root, filename))

    li = []

    for filename in matches:
        with open(filename) as f:
            df = json.load(f)
            li.append(df)
    frame = pandas.DataFrame(li)
    return frame

# %%
df = genDataframeFor()

# %%
df
# Out:
#                                                     gav   timestamp  \
# 0     {'version': '3.9', 'groupId': 'org.apache.poi'...  2018-11-30
# 1     {'artifactId': 'jackson-databind', 'groupId': ...  2018-11-30
# 2     {'version': '2.6.7', 'groupId': 'com.fasterxml...  2018-11-30
# 3     {'version': '2.5.3', 'groupId': 'com.fasterxml...  2018-11-30
# 4     {'groupId': 'rubygems', 'version': '0.9.5', 'a...  2018-11-30
# ...                                                 ...         ...
# 2553  {'artifactId': 'jruby', 'groupId': 'org.jruby'...  2018-11-30
# 2554  {'version': '4.3.9.RELEASE', 'groupId': 'org.s...  2018-11-30
# 2555  {'artifactId': 'jackson-databind', 'groupId': ...  2018-11-30
# 2556  {'artifactId': 'jruby-openssl', 'groupId': 'ru...  2018-11-30
# 2557  {'version': '3.2.5.RELEASE', 'groupId': 'org.s...  2018-11-30
#
#                  cve                                            comment  \
# 0     CVE-2017-12626    https://nvd.nist.gov/vuln/detail/CVE-2017-12626
# 1      CVE-2018-7489
# 2      CVE-2018-5968
# 3     CVE-2018-14720  {"artifacts": ["jackson-databind[<2.6.7.2)||[2...
# 4      CVE-2012-5370  main dependency jruby is affected, but not thi...
# ...              ...                                                ...
# 2553   CVE-2012-5370            https://www.securityfocus.com/bid/56669
# 2554  CVE-2018-11039  {"artifacts": ["spring-web"], "references": ["...
# 2555  CVE-2018-14718  {"artifacts": ["jackson-databind[<2.6.7.2)||[2...
# 2556   CVE-2012-0884        different implementation, only name matches
# 2557   CVE-2016-5007  {"artifacts": ["spring-security", "spring-mvc"...
#
#       vulnerable                                            details
# 0          False  [{'diff': '{"lhs" : {"LOG":"<org.apache.poi.hp...
# 1           True  [{'affectedFile': '/com/fasterxml/jackson/data...
# 2          False  [{'commit': '038b471e2efde2e8f96b4e0be958d3e5a...
# 3           True                                                 []
# 4          False                                                 []
# ...          ...                                                ...
# 2553        True                                                 []
# 2554       False  [{'qname': 'org.springframework.web.filter.Hid...
# 2555        True                                                 []
# 2556       False                                                 []
# 2557       False                                                 []
#
# [2558 rows x 6 columns]

# %%
gavs = pandas.json_normalize(df['gav'])
gavs
# Out:
#             version                     groupId        artifactId
# 0               3.9              org.apache.poi               poi
# 1             2.7.5  com.fasterxml.jackson.core  jackson-databind
# 2             2.6.7  com.fasterxml.jackson.core  jackson-databind
# 3             2.5.3  com.fasterxml.jackson.core  jackson-databind
# 4             0.9.5                    rubygems     jruby-openssl
# ...             ...                         ...               ...
# 2553        1.6.5.1                   org.jruby             jruby
# 2554  4.3.9.RELEASE         org.springframework       spring-core
# 2555          2.9.3  com.fasterxml.jackson.core  jackson-databind
# 2556         0.9.10                    rubygems     jruby-openssl
# 2557  3.2.5.RELEASE         org.springframework       spring-core
#
# [2558 rows x 3 columns]

# %%
df_complete=df.join(gavs)
df_complete
# Out:
#                                                     gav   timestamp  \
# 0     {'version': '3.9', 'groupId': 'org.apache.poi'...  2018-11-30
# 1     {'artifactId': 'jackson-databind', 'groupId': ...  2018-11-30
# 2     {'version': '2.6.7', 'groupId': 'com.fasterxml...  2018-11-30
# 3     {'version': '2.5.3', 'groupId': 'com.fasterxml...  2018-11-30
# 4     {'groupId': 'rubygems', 'version': '0.9.5', 'a...  2018-11-30
# ...                                                 ...         ...
# 2553  {'artifactId': 'jruby', 'groupId': 'org.jruby'...  2018-11-30
# 2554  {'version': '4.3.9.RELEASE', 'groupId': 'org.s...  2018-11-30
# 2555  {'artifactId': 'jackson-databind', 'groupId': ...  2018-11-30
# 2556  {'artifactId': 'jruby-openssl', 'groupId': 'ru...  2018-11-30
# 2557  {'version': '3.2.5.RELEASE', 'groupId': 'org.s...  2018-11-30
#
#                  cve                                            comment  \
# 0     CVE-2017-12626    https://nvd.nist.gov/vuln/detail/CVE-2017-12626
# 1      CVE-2018-7489
# 2      CVE-2018-5968
# 3     CVE-2018-14720  {"artifacts": ["jackson-databind[<2.6.7.2)||[2...
# 4      CVE-2012-5370  main dependency jruby is affected, but not thi...
# ...              ...                                                ...
# 2553   CVE-2012-5370            https://www.securityfocus.com/bid/56669
# 2554  CVE-2018-11039  {"artifacts": ["spring-web"], "references": ["...
# 2555  CVE-2018-14718  {"artifacts": ["jackson-databind[<2.6.7.2)||[2...
# 2556   CVE-2012-0884        different implementation, only name matches
# 2557   CVE-2016-5007  {"artifacts": ["spring-security", "spring-mvc"...
#
#       vulnerable                                            details  \
# 0          False  [{'diff': '{"lhs" : {"LOG":"<org.apache.poi.hp...
# 1           True  [{'affectedFile': '/com/fasterxml/jackson/data...
# 2          False  [{'commit': '038b471e2efde2e8f96b4e0be958d3e5a...
# 3           True                                                 []
# 4          False                                                 []
# ...          ...                                                ...
# 2553        True                                                 []
# 2554       False  [{'qname': 'org.springframework.web.filter.Hid...
# 2555        True                                                 []
# 2556       False                                                 []
# 2557       False                                                 []
#
#             version                     groupId        artifactId
# 0               3.9              org.apache.poi               poi
# 1             2.7.5  com.fasterxml.jackson.core  jackson-databind
# 2             2.6.7  com.fasterxml.jackson.core  jackson-databind
# 3             2.5.3  com.fasterxml.jackson.core  jackson-databind
# 4             0.9.5                    rubygems     jruby-openssl
# ...             ...                         ...               ...
# 2553        1.6.5.1                   org.jruby             jruby
# 2554  4.3.9.RELEASE         org.springframework       spring-core
# 2555          2.9.3  com.fasterxml.jackson.core  jackson-databind
# 2556         0.9.10                    rubygems     jruby-openssl
# 2557  3.2.5.RELEASE         org.springframework       spring-core
#
# [2558 rows x 9 columns]

# %% [markdown]
# ## Num. of unq. CVEs

# %%
df_complete['cve'].nunique()
# Out:
# 251

# %% [markdown]
# ## Num. of unq. GAVs

# %%
df_complete['gav_new'] = df_complete['groupId']+df_complete['artifactId']+df_complete['version']

# %%
df_complete['gav_new'].nunique()
# Out:
# 534

# %% [markdown]
# ## Stats about artifact

# %%
df_ga = df_complete.groupby(['groupId','artifactId'])

# %%
df_ga.size()
# Out:
# groupId                           artifactId
# axis                              axis                        3
# bouncycastle                      bcprov-jdk14               13
# com.fasterxml.jackson.core        jackson-databind          606
# com.fasterxml.jackson.dataformat  jackson-dataformat-xml     77
# com.google.guava                  guava                      25
#                                                            ...
# org.springframework               spring-webmvc              33
# p2.eclipse-plugin                 org.apache.axis             1
# rubygems                          jruby-openssl             438
# stax                              stax                        1
# taglibs                           standard                    1
# Length: 69, dtype: int64

# %%
#import tabulate
md_table = df_ga.size().to_markdown()

# %%
with open("mdtable.md", "w") as text_file:
    text_file.write(md_table)
